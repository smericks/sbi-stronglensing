# %%
# imports

# %% [markdown]
# First, let's test simple data loading

# %%
from src.training.data_loader import load_hdf5_images, load_hdf5_labels

label_list = []
h5_file_path = ''
load_hdf5_labels()
load_hdf5_images()
